# %% [markdown]
# <a href="https://colab.research.google.com/github/Basu-Sir/EDA_25BDS0265/blob/main/Experiment_5_(04_08_2026)/Normalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

data = {
    'Age':[21,45,30,42,50],
    'Bank_Balance': [1200, 85000, 4500, 75000000, 150000] # 75,000,000 is the outlier
}

df = pd.DataFrame(data)

print("Original Data:\n", df, "\n")
# Out:
# Original Data:
#     Age  Bank_Balance
# 0   21          1200
# 1   45         85000
# 2   30          4500
# 3   42      75000000
# 4   50        150000

# %%
min_max_scaler = MinMaxScaler()
df_min_max = pd.DataFrame(
 min_max_scaler.fit_transform(df),
 columns=df.columns
)
print("Min-Max Scaled Data:\n", df_min_max, "\n")
# Out:
# Min-Max Scaled Data:
#          Age  Bank_Balance
# 0  0.000000      0.000000
# 1  0.827586      0.001117
# 2  0.310345      0.000044
# 3  0.724138      1.000000
# 4  1.000000      0.001984

# %%
standard_scaler = StandardScaler()
df_standard = pd.DataFrame(
 standard_scaler.fit_transform(df),
 columns=df.columns
)
print("Standardized Data:\n", df_standard, "\n")
# Out:
# Standardized Data:
#          Age  Bank_Balance
# 0 -1.566875     -0.501967
# 1  0.698486     -0.499171
# 2 -0.717364     -0.501856
# 3  0.415316      1.999997
# 4  1.170436     -0.497003
